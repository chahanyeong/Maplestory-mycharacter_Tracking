# %% [markdown]
# # Tracking with detect, Reid model

# %% [markdown]
# # Install

# %%
# !pip install --upgrade pip setuptools wheel
# !git clone https://github.com/mikel-brostrom/yolo_tracking.git  # clone repo
# %cd yolo_tracking
# !pip install -e .


import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.2.1+cu121 (Tesla T4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#동영상, 가중치는 google drive 안에서 꺼내옴 -> 맞게 수정

# %%
# %pwd
# Out:
# '/content/yolo_tracking'

# %%
# !yes | ffmpeg -ss 00:00:00 -i /content/drive/MyDrive/fighting_short.mp4 -to 00:00:09 -vf fps=30 out.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# # Run inference on video(yolov8 customed)time

# %%
#tracking -> track.py에서 yolo 가중치 수정

# %%
# !python tracking/track.py --reid-model osnet_x0_25_msmt17.pt --tracking-method botsort --source out.mp4 --save --conf 0.01 #여기서 conf,iou 파라미터 조정
# Out:
# 2024-04-06 05:37:27.411 | SUCCESS  | boxmot.appearance.reid_model_factory:load_pretrained_weights:207 - Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# video 1/1 (1/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 79.6ms
# video 1/1 (2/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.7ms
# video 1/1 (3/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.7ms
# video 1/1 (4/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.8ms
# video 1/1 (5/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.7ms
# video 1/1 (6/270) /content/yolo_tracking/out.mp4: 384x640 2 CHYs, 10.8ms
# video 1/1 (7/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.7ms
# video 1/1 (8/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.7ms
# video 1/1 (9/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.7ms
# video 1/1 (10/270) /content/yolo_tracking/out.mp4: 384x640 1 CHY, 10.8ms
# video 1/1 (11/270) /content/yolo_tracking/out.mp4: 384x640 3 CHYs, 10.7ms
# ...

# %%
# !ffmpeg -i out.avi -vf fps=30 -vcodec libx264 output.mp4

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# https://stackoverflow.com/questions/57377185/how-play-mp4-video-in-google-colab
#
# Compress the video file to a format supported by Google Colab (mpeg4 (native) -> h264 (libx264))
